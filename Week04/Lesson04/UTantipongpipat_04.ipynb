# %%
import pandas as pd
surveys_df = pd.read_csv("surveys.csv",
                         keep_default_na=False, na_values=[""])
surveys_df
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL    M             32.0
# 1              2      7   16  1977        3         NL    M             33.0
# 2              3      7   16  1977        2         DM    F             37.0
# 3              4      7   16  1977        7         DM    M             36.0
# 4              5      7   16  1977        3         DM    M             35.0
# 5              6      7   16  1977        1         PF    M             14.0
# 6              7      7   16  1977        2         PE    F              NaN
# 7              8      7   16  1977        1         DM    M             37.0
# 8              9      7   16  1977        1         DM    F             34.0
# 9             10      7   16  1977        6         PF    F             20.0
# 10            11      7   16  1977        5         DS    F             53.0
# ...

# %%
species_df = pd.read_csv("species.csv",
                         keep_default_na=False, na_values=[""])
species_df
# Out:
#    species_id             genus          species     taxa
# 0          AB        Amphispiza        bilineata     Bird
# 1          AH  Ammospermophilus          harrisi   Rodent
# 2          AS        Ammodramus       savannarum     Bird
# 3          BA           Baiomys          taylori   Rodent
# 4          CB   Campylorhynchus  brunneicapillus     Bird
# 5          CM       Calamospiza      melanocorys     Bird
# 6          CQ        Callipepla         squamata     Bird
# 7          CS          Crotalus       scutalatus  Reptile
# 8          CT     Cnemidophorus           tigris  Reptile
# 9          CU     Cnemidophorus        uniparens  Reptile
# 10         CV          Crotalus          viridis  Reptile
# 11         DM         Dipodomys         merriami   Rodent
# 12         DO         Dipodomys            ordii   Rodent
# 13         DS         Dipodomys      spectabilis   Rodent
# 14         DX         Dipodomys              sp.   Rodent
# ...

# %%
# read in first 10 lines of surveys table
survey_sub = surveys_df.head(10)
# grab the last 10 rows 
survey_sub_last10 = surveys_df.tail(10)
#reset the index values to the second dataframe appends properly
survey_sub_last10=survey_sub_last10.reset_index(drop=True)
# drop=True option avoids adding new index column with old index values

# %%
# stack the DataFrames on top of each other
vertical_stack = pd.concat([survey_sub, survey_sub_last10], axis=0)

# place the DataFrames side by side
horizontal_stack = pd.concat([survey_sub, survey_sub_last10], axis=1)

# %%
vertical_stack
# Out:
#    record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL    M             32.0
# 1          2      7   16  1977        3         NL    M             33.0
# 2          3      7   16  1977        2         DM    F             37.0
# 3          4      7   16  1977        7         DM    M             36.0
# 4          5      7   16  1977        3         DM    M             35.0
# 5          6      7   16  1977        1         PF    M             14.0
# 6          7      7   16  1977        2         PE    F              NaN
# 7          8      7   16  1977        1         DM    M             37.0
# 8          9      7   16  1977        1         DM    F             34.0
# 9         10      7   16  1977        6         PF    F             20.0
# 0      35540     12   31  2002       15         PB    F             26.0
# 1      35541     12   31  2002       15         PB    F             24.0
# ...

# %%
horizontal_stack
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
# 5          6      7   16  1977        1         PF   M             14.0
# 6          7      7   16  1977        2         PE   F              NaN
# 7          8      7   16  1977        1         DM   M             37.0
# 8          9      7   16  1977        1         DM   F             34.0
# 9         10      7   16  1977        6         PF   F             20.0
#
#    weight  record_id  month  day  year  plot_id species_id  sex  \
# 0     NaN      35540     12   31  2002       15         PB    F
# ...

# %%
# Write DataFrame to CSV
vertical_stack.to_csv('out.csv', index=False)

# %%
# for kicks read our output back into python and make sure all looks good
new_output = pd.read_csv('out.csv', keep_default_na=False, na_values=[""])
new_output
# Out:
#     record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0           1      7   16  1977        2         NL    M             32.0
# 1           2      7   16  1977        3         NL    M             33.0
# 2           3      7   16  1977        2         DM    F             37.0
# 3           4      7   16  1977        7         DM    M             36.0
# 4           5      7   16  1977        3         DM    M             35.0
# 5           6      7   16  1977        1         PF    M             14.0
# 6           7      7   16  1977        2         PE    F              NaN
# 7           8      7   16  1977        1         DM    M             37.0
# 8           9      7   16  1977        1         DM    F             34.0
# 9          10      7   16  1977        6         PF    F             20.0
# 10      35540     12   31  2002       15         PB    F             26.0
# 11      35541     12   31  2002       15         PB    F             24.0
# ...

# %%
# read in first 10 lines of surveys table
survey_sub = surveys_df.head(10)

survey_sub
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
# 5          6      7   16  1977        1         PF   M             14.0
# 6          7      7   16  1977        2         PE   F              NaN
# 7          8      7   16  1977        1         DM   M             37.0
# 8          9      7   16  1977        1         DM   F             34.0
# 9         10      7   16  1977        6         PF   F             20.0
#
#    weight
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN

# %%
# import a small subset of the species data designed for this part of the lesson.
# It is stored in the data folder.
#species_sub = pd.read_csv('speciesSubset.csv', keep_default_na=False, na_values=[""])

species_sub
# Out:
#   species_id       genus   species    taxa
# 0         DM   Dipodomys  merriami  Rodent
# 1         NL     Neotoma  albigula  Rodent
# 2         PE  Peromyscus  eremicus  Rodent

# %%
"""
>>> species_sub.columns

Index([u'species_id', u'genus', u'species', u'taxa'], dtype='object')

>>> survey_sub.columns

Index([u'record_id', u'month', u'day', u'year', u'plot_id', u'species_id',
       u'sex', u'hindfoot_length', u'weight'], dtype='object')
       
       """
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-aed475be0f8b> in <module>()
# ----> 1 species_sub.columns = Index([u'species_id', u'genus', u'species', u'taxa'], dtype='object')
#       2
#       3 survey_sub.columns
#       4
#       5 Index([u'record_id', u'month', u'day', u'year', u'plot_id', u'species_id',
#
# NameError: name 'Index' is not defined

# %%
merged_inner = pd.merge(left=survey_sub,right=species_sub, left_on='species_id', right_on='species_id')
# in this case `species_id` is the only column name in  both dataframes, so if we skippd `left_on`
# and `right_on` arguments we would still get the same result

# what's the size of the output data?
merged_inner.shape
merged_inner
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
# 5          8      7   16  1977        1         DM   M             37.0
# 6          9      7   16  1977        1         DM   F             34.0
# 7          7      7   16  1977        2         PE   F              NaN
#
#    weight       genus   species    taxa
# 0     NaN     Neotoma  albigula  Rodent
# 1     NaN     Neotoma  albigula  Rodent
# 2     NaN   Dipodomys  merriami  Rodent
# 3     NaN   Dipodomys  merriami  Rodent
# 4     NaN   Dipodomys  merriami  Rodent
# 5     NaN   Dipodomys  merriami  Rodent
# ...

# %%
merged_left = pd.merge(left=survey_sub,right=species_sub, how='left', left_on='species_id', right_on='species_id')

merged_left
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
# 5          6      7   16  1977        1         PF   M             14.0
# 6          7      7   16  1977        2         PE   F              NaN
# 7          8      7   16  1977        1         DM   M             37.0
# 8          9      7   16  1977        1         DM   F             34.0
# 9         10      7   16  1977        6         PF   F             20.0
#
#    weight       genus   species    taxa
# 0     NaN     Neotoma  albigula  Rodent
# 1     NaN     Neotoma  albigula  Rodent
# 2     NaN   Dipodomys  merriami  Rodent
# ...

# %%
merged_left[ pd.isnull(merged_left.genus) ]
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 5          6      7   16  1977        1         PF   M             14.0
# 9         10      7   16  1977        6         PF   F             20.0
#
#    weight genus species taxa
# 5     NaN   NaN     NaN  NaN
# 9     NaN   NaN     NaN  NaN

# %%
#challenge part

full_merged_left = pd.merge(left=surveys_df,right=species_df, how='left', left_on='species_id', right_on='species_id')
full_merged_left
#this get all taxa of all species id in species_df.
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL    M             32.0
# 1              2      7   16  1977        3         NL    M             33.0
# 2              3      7   16  1977        2         DM    F             37.0
# 3              4      7   16  1977        7         DM    M             36.0
# 4              5      7   16  1977        3         DM    M             35.0
# 5              6      7   16  1977        1         PF    M             14.0
# 6              7      7   16  1977        2         PE    F              NaN
# 7              8      7   16  1977        1         DM    M             37.0
# 8              9      7   16  1977        1         DM    F             34.0
# 9             10      7   16  1977        6         PF    F             20.0
# 10            11      7   16  1977        5         DS    F             53.0
# ...

# %%
#https://stackoverflow.com/questions/21331722/plot-number-of-occurrences-from-pandas-dataframe
#then look up .size() method
dis_by_taxa = full_merged_left.groupby(['plot_id','taxa']).size()#.plot(kind='bar')
dis_by_taxa

dis_by_taxa = full_merged_left.groupby(['plot_id','taxa']).size().unstack(fill_value=0) #fix a long list into groups
dis_by_taxa
# Out:
# taxa     Bird  Rabbit  Reptile  Rodent
# plot_id
# 1          11       2        0    1976
# 2          17       3        1    2170
# 3          17       5        0    1786
# 4           5       0        0    1955
# 5           5       1        0    1144
# 6          20       0        1    1541
# 7          28       0        1     700
# 8          10       1        1    1869
# 9          13       1        0    1915
# 10         12      10        0     302
# 11         10       5        2    1895
# 12         31       8        0    2324
# 13         48       1        1    1481
# 14         17       4        0    1859
# 15         23       3        1     997
# 16         15       3        0     531
# 17          4       6        1    2026
# 18         12       1        0    1426
# 19         14       8        1    1128
# 20         51       0        2    1321
# 21         13       1        1    1120
# 22         16       2        1    1368
# 23         41       8        0     407
# ...

# %%
# %matplotlib inline
dis_by_taxa.plot(kind='bar', stacked=True)

# %%
dis_by_taxa_sex = full_merged_left.groupby(['plot_id','sex','taxa']).size().unstack(fill_value=0)
dis_by_taxa_sex
# Out:
# taxa         Rodent
# plot_id sex
# 1       F       848
#         M      1095
# 2       F       970
#         M      1144
# 3       F       893
#         M       840
# 4       F       872
#         M      1030
# 5       F       527
#         M       586
# 6       F       737
#         M       764
# 7       F       335
#         M       307
# 8       F       840
#         M       983
# 9       F       853
#         M      1004
# 10      F       141
#         M       142
# 11      F       822
#         M      1029
# 12      F      1060
#         M      1200
# 13      F       628
#         M       783
# 14      F       709
#         M      1070
# 15      F       481
#         M       409
# 16      F       222
#         M       273
# 17      F       892
#         M      1053
# 18      F       755
#         M       626
# 19      F       522
#         M       581
# 20      F       650
#         M       613
# 21      F       611
#         M       451
# 22      F       671
# ...

# %%
# %matplotlib inline
dis_by_taxa_sex.plot(kind='bar', stacked=True)

# %%
#all are rodents... so can get rid of taxa actually...
dis_by_taxa_sex = full_merged_left.groupby(['plot_id','sex']).size().unstack(fill_value=0)
dis_by_taxa_sex
# %matplotlib inline
dis_by_taxa_sex.plot(kind='bar', stacked=True)
