# %%
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-02aeb6e281ab> in <module>()
# ----> 1 from ggplot import *
#
# ModuleNotFoundError: No module named 'ggplot'

# %% [markdown]
# # Using surveys instead of surveys_complete, couldn't find that file

# %%
import pandas as pd

surveys_complete = pd.read_csv( 'data/surveys.csv', index_col=0)
surveys_complete.index.name = 'X'
surveys_complete
# Out:
#        month  day  year  plot_id species_id  sex  hindfoot_length  weight
# X
# 1          7   16  1977        2         NL    M             32.0     NaN
# 2          7   16  1977        3         NL    M             33.0     NaN
# 3          7   16  1977        2         DM    F             37.0     NaN
# 4          7   16  1977        7         DM    M             36.0     NaN
# 5          7   16  1977        3         DM    M             35.0     NaN
# 6          7   16  1977        1         PF    M             14.0     NaN
# 7          7   16  1977        2         PE    F              NaN     NaN
# 8          7   16  1977        1         DM    M             37.0     NaN
# 9          7   16  1977        1         DM    F             34.0     NaN
# 10         7   16  1977        6         PF    F             20.0     NaN
# 11         7   16  1977        5         DS    F             53.0     NaN
# 12         7   16  1977        7         DM    M             38.0     NaN
# 13         7   16  1977        3         DM    M             35.0     NaN
# 14         7   16  1977        8         DM  NaN              NaN     NaN
# 15         7   16  1977        6         DM    F             36.0     NaN
# 16         7   16  1977        4         DM    F             36.0     NaN
# 17         7   16  1977        3         DS    F             48.0     NaN
# 18         7   16  1977        2         PP    M             22.0     NaN
# 19         7   16  1977        4         PF  NaN              NaN     NaN
# 20         7   17  1977       11         DS    F             48.0     NaN
# 21         7   17  1977       14         DM    F             34.0     NaN
# 22         7   17  1977       15         NL    F             31.0     NaN
# 23         7   17  1977       13         DM    M             36.0     NaN
# 24         7   17  1977       13         SH    M             21.0     NaN
# 25         7   17  1977        9         DM    M             35.0     NaN
# 26         7   17  1977       15         DM    M             31.0     NaN
# 27         7   17  1977       15         DM    M             36.0     NaN
# 28         7   17  1977       11         DM    M             38.0     NaN
# 29         7   17  1977       11         PP    M              NaN     NaN
# 30         7   17  1977       10         DS    F             52.0     NaN
# ...      ...  ...   ...      ...        ...  ...              ...     ...
# 35520     12   31  2002        9         SF  NaN             24.0    36.0
# 35521     12   31  2002        9         DM    M             37.0    48.0
# 35522     12   31  2002        9         DM    F             35.0    45.0
# 35523     12   31  2002        9         DM    F             36.0    44.0
# 35524     12   31  2002        9         PB    F             25.0    27.0
# 35525     12   31  2002        9         OL    M             21.0    26.0
# 35526     12   31  2002        8         OT    F             20.0    24.0
# 35527     12   31  2002       13         DO    F             33.0    43.0
# 35528     12   31  2002       13         US  NaN              NaN     NaN
# 35529     12   31  2002       13         PB    F             25.0    25.0
# 35530     12   31  2002       13         OT    F             20.0     NaN
# 35531     12   31  2002       13         PB    F             27.0     NaN
# 35532     12   31  2002       14         DM    F             34.0    43.0
# 35533     12   31  2002       14         DM    F             36.0    48.0
# 35534     12   31  2002       14         DM    M             37.0    56.0
# 35535     12   31  2002       14         DM    M             37.0    53.0
# 35536     12   31  2002       14         DM    F             35.0    42.0
# 35537     12   31  2002       14         DM    F             36.0    46.0
# 35538     12   31  2002       15         PB    F             26.0    31.0
# 35539     12   31  2002       15         SF    M             26.0    68.0
# 35540     12   31  2002       15         PB    F             26.0    23.0
# 35541     12   31  2002       15         PB    F             24.0    31.0
# 35542     12   31  2002       15         PB    F             26.0    29.0
# 35543     12   31  2002       15         PB    F             27.0    34.0
# 35544     12   31  2002       15         US  NaN              NaN     NaN
# 35545     12   31  2002       15         AH  NaN              NaN     NaN
# 35546     12   31  2002       15         AH  NaN              NaN     NaN
# 35547     12   31  2002       10         RM    F             15.0    14.0
# 35548     12   31  2002        7         DO    M             36.0    51.0
# 35549     12   31  2002        5        NaN  NaN              NaN     NaN
#
# [35549 rows x 8 columns]

# %%
from ggplot import *

# %%
# %matplotlib notebook
ggplot( aesthetics= aes(x = 'weight', y = 'hindfoot_length'), data = surveys_complete)
# Out:
# <img src="data:image/png;base64,..." width="792">
# <ggplot: (-9223372036561490102)>

# %%
# Create
surveys_plot = ggplot( aes(x = 'weight', y = 'hindfoot_length'), data = surveys_complete)

# Draw the plot
surveys_plot + geom_point()
# Out:
# <img src="data:image/png;base64,..." width="792">
# <ggplot: (293824951)>

# %%
ggplot(aes(x = 'weight', y = 'hindfoot_length'), data = surveys_complete) + \
    geom_point(alpha = 0.1)
# Out:
# <img src="data:image/png;base64,..." width="792">
# <ggplot: (-9223372036561626396)>

# %%
ggplot(aes(x = 'weight', y = 'hindfoot_length'),data = surveys_complete) + \
    geom_point(alpha = 0.1, color = "blue")
# Out:
# <img src="data:image/png;base64,..." width="792">
# <ggplot: (295273585)>

# %%
# ggplot(data = surveys_complete, aes(x = weight, y = hindfoot_length)) +
#    geom_point(alpha = 0.1, aes(color=species_id))

ggplot(aes(x = 'weight', y = 'hindfoot_length',color='plot_id'),data = surveys_complete) + \
    geom_point( alpha = 0.1)
# Out:
# <img src="data:image/png;base64,..." width="792">
# <ggplot: (312840596)>

# %%
ggplot( aes(x = 'species_id', y = 'hindfoot_length'), data = surveys_complete) + geom_boxplot()
# Out:
# <img src="data:image/png;base64,..." width="792">
# <ggplot: (309935466)>

# %% [markdown]
# # I'm starting to think the reason the previous plot was unable to plot by species_id is that in survey.csv the species values are strings rather than numbers?

# %%
#surveys_complete['species_factor'] = surveys_complete['species_id'].astype('category').cat.codes

#xlabels = sorted(set(surveys_complete['species_id'].values) )
#xcodes = sorted(set(surveys_complete['species_factor'].values))

#ggplot(aes(x = 'species_factor', y = 'hindfoot_length'),data = surveys_complete) + \
#    geom_point(position='jitter',alpha=0.7,jittersize=0.4) + \
#        scale_x_continuous(breaks=xcodes, labels=xlabels) + \
#                         xlab('species_id') + geom_boxplot(alpha=0)

# %%
#yearly_counts = surveys_complete[['year','species_id','species']].groupby(['year', 'species_id']).count().reset_index()
#yearly_counts.columns = ['year','species_id', 'n']
#yearly_counts
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-35-d2ff00d95967> in <module>()
# ----> 1 yearly_counts = surveys_complete[['year','species_id','species']].groupby(['year', 'species_id']).count().reset_index()
#       2 yearly_counts.columns = ['year','species_id', 'n']
#       3 yearly_counts
#
# /usr/local/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    1956         if isinstance(key, (Series, np.ndarray, Index, list)):
#    1957             # either boolean or fancy integer index
# -> 1958             return self._getitem_array(key)
#    1959         elif isinstance(key, DataFrame):
#    1960             return self._getitem_frame(key)
#
# /usr/local/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2000             return self.take(indexer, axis=0, convert=False)
#    2001         else:
# -> 2002             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2003             return self.take(indexer, axis=1, convert=True)
#    2004
#
# /usr/local/lib/python3.6/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter)
#    1229                 mask = check == -1
#    1230                 if mask.any():
# -> 1231                     raise KeyError('%s not in index' % objarr[mask])
#    1232
#    1233                 return _values_from_object(indexer)
#
# KeyError: "['species'] not in index"
