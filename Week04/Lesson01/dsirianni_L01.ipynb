# %%
import pandas as pd

# %%
# note that pd.read_csv is used because we imported pandas as pd
pd.read_csv("surveys.csv")
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL    M             32.0
# 1              2      7   16  1977        3         NL    M             33.0
# 2              3      7   16  1977        2         DM    F             37.0
# 3              4      7   16  1977        7         DM    M             36.0
# 4              5      7   16  1977        3         DM    M             35.0
# 5              6      7   16  1977        1         PF    M             14.0
# 6              7      7   16  1977        2         PE    F              NaN
# 7              8      7   16  1977        1         DM    M             37.0
# 8              9      7   16  1977        1         DM    F             34.0
# 9             10      7   16  1977        6         PF    F             20.0
# 10            11      7   16  1977        5         DS    F             53.0
# ...

# %%
surveys_df = pd.read_csv("surveys.csv")
surveys_df
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL    M             32.0
# 1              2      7   16  1977        3         NL    M             33.0
# 2              3      7   16  1977        2         DM    F             37.0
# 3              4      7   16  1977        7         DM    M             36.0
# 4              5      7   16  1977        3         DM    M             35.0
# 5              6      7   16  1977        1         PF    M             14.0
# 6              7      7   16  1977        2         PE    F              NaN
# 7              8      7   16  1977        1         DM    M             37.0
# 8              9      7   16  1977        1         DM    F             34.0
# 9             10      7   16  1977        6         PF    F             20.0
# 10            11      7   16  1977        5         DS    F             53.0
# ...

# %%
type(surveys_df)
# this does the same thing as the above!
surveys_df.__class__
# Out:
# pandas.core.frame.DataFrame

# %%
surveys_df.dtypes
# Out:
# record_id            int64
# month                int64
# day                  int64
# year                 int64
# plot_id              int64
# species_id          object
# sex                 object
# hindfoot_length    float64
# weight             float64
# dtype: object

# %%
# Look at the column names
surveys_df.columns.values
# Out:
# array(['record_id', 'month', 'day', 'year', 'plot_id', 'species_id', 'sex',
#        'hindfoot_length', 'weight'], dtype=object)

# %%
pd.unique(surveys_df['species_id'])
# Out:
# array(['NL', 'DM', 'PF', 'PE', 'DS', 'PP', 'SH', 'OT', 'DO', 'OX', 'SS',
#        'OL', 'RM', nan, 'SA', 'PM', 'AH', 'DX', 'AB', 'CB', 'CM', 'CQ',
#        'RF', 'PC', 'PG', 'PH', 'PU', 'CV', 'UR', 'UP', 'ZL', 'UL', 'CS',
#        'SC', 'BA', 'SF', 'RO', 'AS', 'SO', 'PI', 'ST', 'CU', 'SU', 'RX',
#        'PB', 'PL', 'PX', 'CT', 'US'], dtype=object)

# %%
surveys_df['weight'].describe()
# Out:
# count    32283.000000
# mean        42.672428
# std         36.631259
# min          4.000000
# 25%         20.000000
# 50%         37.000000
# 75%         48.000000
# max        280.000000
# Name: weight, dtype: float64

# %%
surveys_df['weight'].min()
surveys_df['weight'].max()
surveys_df['weight'].mean()
surveys_df['weight'].std()
surveys_df['weight'].count() #seems to return only the last thing
# Out:
# 32283

# %%
# Group data by sex
grouped_data = surveys_df.groupby('sex')

# %%
# summary statistics for all numeric columns by sex
grouped_data.describe()
# provide the mean for each numeric column by sex
grouped_data.mean()
# Out:
#         record_id     month        day         year    plot_id  \
# sex
# F    18036.412046  6.583047  16.007138  1990.644997  11.440854
# M    17754.835601  6.392668  16.184286  1990.480401  11.098282
#
#      hindfoot_length     weight
# sex
# F          28.836780  42.170555
# M          29.709578  42.995379

# %%
# count the number of samples by species
species_counts = surveys_df.groupby('species_id')['record_id'].count()
print(species_counts)
# Out:
# species_id
# AB      303
# AH      437
# AS        2
# BA       46
# CB       50
# CM       13
# CQ       16
# CS        1
# CT        1
# CU        1
# CV        1
# DM    10596
# DO     3027
# DS     2504
# DX       40
# NL     1252
# OL     1006
# OT     2249
# OX       12
# PB     2891
# PC       39
# PE     1299
# PF     1597
# PG        8
# PH       32
# PI        9
# PL       36
# PM      899
# PP     3123
# PU        5
# PX        6
# RF       75
# RM     2609
# RO        8
# RX        2
# SA       75
# SC        1
# SF       43
# SH      147
# SO       43
# SS      248
# ST        1
# SU        5
# UL        4
# UP        8
# UR       10
# US        4
# ZL        2
# Name: record_id, dtype: int64

# %%
surveys_df.groupby('species_id')['record_id'].count()['DO'] #the .groupby.count() returns a table, so get only the row with 'DO'
#type(surveys_df.groupby('species_id')['record_id'].count())
# Out:
# pandas.core.series.Series

# %%
# multiply all weight values by 2
surveys_df['weight']*2
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN
# 10         NaN
# 11         NaN
# 12         NaN
# 13         NaN
# 14         NaN
# 15         NaN
# 16         NaN
# 17         NaN
# 18         NaN
# 19         NaN
# 20         NaN
# 21         NaN
# 22         NaN
# 23         NaN
# 24         NaN
# 25         NaN
# 26         NaN
# 27         NaN
# 28         NaN
# 29         NaN
#          ...
# 35519     72.0
# 35520     96.0
# 35521     90.0
# 35522     88.0
# 35523     54.0
# 35524     52.0
# 35525     48.0
# 35526     86.0
# 35527      NaN
# 35528     50.0
# 35529      NaN
# 35530      NaN
# 35531     86.0
# 35532     96.0
# 35533    112.0
# 35534    106.0
# 35535     84.0
# 35536     92.0
# 35537     62.0
# 35538    136.0
# 35539     46.0
# 35540     62.0
# 35541     58.0
# 35542     68.0
# 35543      NaN
# 35544      NaN
# 35545      NaN
# ...

# %%
# make sure figures appear inline in Ipython Notebook
# %matplotlib inline
# create a quick bar chart
species_counts.plot(kind='bar');

# %%
total_count = surveys_df.groupby('plot_id')['record_id'].nunique()
# let's plot that too
total_count.plot(kind='bar');
